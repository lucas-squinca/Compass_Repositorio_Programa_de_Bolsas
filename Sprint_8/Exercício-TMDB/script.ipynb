# %%
import requests
import pandas as pd

from IPython.display import display

api_key = "a916f73fafcf8777984abc616dcd6c9f"

url = f"https://api.themoviedb.org/3/movie/top_rated?api_key={api_key}&language=pt-BR"

response = requests.get(url)
data = response.json()

filmes = []

for movie in data['results']:
    df = {'Titulo': movie['title'],
    'Data de lançamento': movie['release_date'],
    'Visão geral': movie['overview'],
    'Votos': movie['vote_count'],
    'Média de votos:': movie['vote_average']}

    filmes.append(df)

    df = pd.DataFrame(filmes)
    
display(df)
# Out:
#                                    Titulo Data de lançamento  \
# 0                       O Poderoso Chefão         1972-03-14
# 1                   Um Sonho de Liberdade         1994-09-23
# 2             O Poderoso Chefão: Parte II         1974-12-20
# 3                    A Lista de Schindler         1993-12-15
# 4               Dilwale vai levar a noiva         1995-10-20
# 5                12 Homens e uma Sentença         1957-04-10
# 6                     A Viagem de Chihiro         2001-07-20
# 7                                Parasita         2019-05-30
# 8                               Your Name         2016-08-26
# 9          Batman: O Cavaleiro das Trevas         2008-07-16
# 10                 À Espera de um Milagre         1999-12-10
# 11       Pulp Fiction: Tempo de Violência         1994-09-10
# 12  Forrest Gump: O Contador de Histórias         1994-06-23
# 13   O Senhor dos Anéis: O Retorno do Rei         2003-12-01
# 14                Três Homens em Conflito         1966-12-23
# 15                   Os Bons Companheiros         1990-09-12
# 16                          A Vida é Bela         1997-12-20
# 17                 O Túmulo dos Vagalumes         1988-04-16
# 18                        Cinema Paradiso         1988-11-17
# 19                       Os Sete Samurais         1954-04-26
#
#                                           Visão geral  Votos  Média de votos:
# 0   Em 1945, Don Corleone é o chefe de uma mafiosa...  18811              8.7
# 1   Em 1946, Andy Dufresne, um banqueiro jovem e b...  24789              8.7
# 2   Após a máfia matar sua família, o jovem Vito f...  11369              8.6
# 3   O alemão Oskar Schindler viu na mão de obra ju...  14692              8.6
# 4   Raj e Simran são dois jovens indianos vivendo ...   4266              8.6
# 5   Um jovem porto-riquenho é acusado do brutal cr...   7728              8.5
# 6   Chihiro e seus pais estão se mudando para uma ...  15000              8.5
# 7   Toda a família de Ki-taek está desempregada, v...  16542              8.5
# 8   Mitsuha é a filha do prefeito de uma pequena c...  10378              8.5
# 9   Após dois anos desde o surgimento do Batman, o...  30784              8.5
# 10  Milagres acontecem em lugares inesperados, mes...  16040              8.5
# 11  Vincent Vega (John Travolta) e Jules Winnfield...  26032              8.5
# 12  Quarenta anos da história dos Estados Unidos, ...  25548              8.5
# 13  O confronto final entre as forças do bem e do ...  22466              8.5
# 14  Durante o auge da Guerra Civil, um misterioso ...   7816              8.5
# 15  Um jovem cresce na máfia e trabalha arduamente...  11814              8.5
# 16  Durante a Segunda Guerra Mundial na Itália, o ...  12289              8.5
# 17  O filme relata a história de dois irmãos, Seit...   4903              8.5
# 18  Um diretor de cinema lembra como, em sua infân...   3989              8.5
# 19  No século XVI, durante a era Sengoku, quando o...   3262              8.5
